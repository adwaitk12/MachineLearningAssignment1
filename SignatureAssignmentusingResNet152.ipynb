# %% [markdown]
# <a href="https://colab.research.google.com/github/adwaitk12/MachineLearningAssignment1/blob/main/SignatureAssignmentusingResNet152.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')









import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import cv2
import math

import keras
import keras.backend as K
import tensorflow as tf
from keras import applications
from keras.models import Model
from keras.layers import Flatten, Dense, Input,concatenate
from keras.optimizers import Adam
from keras.models import load_model, model_from_json
import random
# Out:
# Mounted at /content/drive/

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import cv2
import math
from tensorflow import keras
import keras
import keras.backend as K
import tensorflow as tf
from keras import applications
from keras.models import Model
from keras.layers import Flatten, Dense, Input,concatenate
from keras.optimizers import Adam
from keras.models import load_model, model_from_json
import random
gen="/content/drive/MyDrive/input/handwritten signatures/sample_Signature/sample_Signature/genuine"
forg="/content/drive/MyDrive/input/handwritten signatures/sample_Signature/sample_Signature/forged"

gentr="/content/drive/MyDrive/input/sigcomp 2009 train/Sigcomp 2009 train/genuine"
forgtr="/content/drive/MyDrive/input/sigcomp 2009 train/Sigcomp 2009 train/forgeries"

gent="/content/drive/MyDrive/input/Sigcomp 2009/sigcomp 2009/genuines"
forgt="/content/drive/MyDrive/input/Sigcomp 2009/sigcomp 2009/forgeries"

# %%
img_width, img_height, channels = 224, 224, 3

dim = (img_width, img_height)

def to_rgb(img):
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA) 
    img_rgb = np.asarray(np.dstack((img, img, img)), dtype=np.uint8)
    return img_rgb

def returnimages(path,img):
    image=cv2.imread(path+"/"+ img)                  #bringing the image
    image=cv2.resize(image, (img_width, img_height))
    image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image=to_rgb(image).reshape(1,img_width, img_height,3)/255.0       #resizing and normalizing    
    return image

def getfiles(num,gen,forg):
    a=os.listdir(gen)
    b=os.listdir(forg)
    c=str(num)
    c=c[2:]
    if(len(c)==2):
        c=c+"0"
    
    n,m=[],[]
    for i in b:
        if i.endswith(c+".png"):
            n=n+[i]
        elif i.endswith(c+".PNG"):
            n=n+[i]
    for i in a:
        if i.endswith(c+".png"):
            m=m+[i]
        elif i.endswith(c+".PNG"):
            m=m+[i]
    return m.pop(),n,m

def getfiles2(num):
    a=os.listdir(gentr)
    b=os.listdir(forgtr)
    c=str(num)
    c=c[2:]
    if(len(c)==2):
        c=c+"0"
    n,m=[],[]
    for i in b:
        if (i.endswith(c+"_001_6g.png") or i.endswith(c+"_002_6g.png") or i.endswith(c+"_003_6g.png")
            or i.endswith(c+"_004_6g.png") or i.endswith(c+"_005_6g.png")):
            n=n+[i]
        elif (i.endswith(c+"_001_6g.PNG") or i.endswith(c+"_002_6g.PNG") or i.endswith(c+"_003_6g.PNG")
              or i.endswith(c+"_004_6g.PNG") or i.endswith(c+"_005_6g.PNG")):
            n=n+[i]
    for i in a:
        if (i.endswith(c+"_001_6g.png") or i.endswith(c+"_002_6g.png") or i.endswith(c+"_003_6g.png")
            or i.endswith(c+"_004_6g.png") or i.endswith(c+"_005_6g.png")):
            m=m+[i]
        elif (i.endswith(c+"_001_6g.PNG") or i.endswith(c+"_002_6g.PNG") or i.endswith(c+"_003_6g.PNG")
              or i.endswith(c+"_004_6g.PNG") or i.endswith(c+"_005_6g.PNG")):
            m=m+[i]
    return m.pop(),n,m

# %%
def triplet_loss(y_true, y_pred):
    alpha = 0.5
    anchor, positive, negative =y_pred[0,0:512], y_pred[0,512:1024], y_pred[0,1024:1536]
    
    positive_distance = K.mean(K.square(anchor - positive),axis=-1)
    negative_distance = K.mean(K.square(anchor - negative),axis=-1)
    return K.mean(K.maximum(0.0, positive_distance - negative_distance + alpha))

# %%
model = keras.applications.ResNet152(weights='imagenet', include_top=False, pooling='max')
for layer in model.layers[:15]:
    layer.trainable = False

anchor_in = Input(shape=(img_width, img_height, channels))
pos_in = Input(shape=(img_width, img_height, channels))
neg_in = Input(shape=(img_width, img_height, channels))

anchor_out = model(anchor_in)
pos_out = model(pos_in)
neg_out = model(neg_in)
merged_vector = concatenate([anchor_out, pos_out, neg_out],axis=1)

model = Model(inputs=[anchor_in, pos_in, neg_in], outputs=merged_vector)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234700800/234698864 [==============================] - 1s 0us/step

# %%
model.compile(optimizer=Adam(lr=0.000005),loss=triplet_loss)

# %%
def generator():
    for i in range(1,31):
        if(i<10):
            anc,neg,pos=getfiles(float("0.00"+str(i)),gen,forg)
        else:
            anc,neg,pos=getfiles(float("0.0"+str(i)),gen,forg)
        for i in range(len(neg)):
            for j in range(len(pos)):
                anchor=returnimages(gen,anc)
                positive=returnimages(gen,pos[j])
                negative=returnimages(forg,neg[i])
               # yield ([anc,pos[j],neg[i]],[0])
                yield ([anchor,positive,negative],np.asarray([0]))

# %%
for x in range(2):
    model.fit_generator(generator() , steps_per_epoch=200,epochs=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/3
# 200/200 [==============================] - 124s 282ms/step - loss: 0.0290
# Epoch 2/3
# 200/200 [==============================] - 56s 276ms/step - loss: 0.0200
# Epoch 3/3
# 200/200 [==============================] - 77s 384ms/step - loss: 0.0119
# Epoch 1/3
# 200/200 [==============================] - 49s 247ms/step - loss: 0.0000e+00
# Epoch 2/3
# 200/200 [==============================] - 49s 246ms/step - loss: 3.3908e-04
# Epoch 3/3
# 200/200 [==============================] - 59s 296ms/step - loss: 0.0000e+00

# %%
model.compile(optimizer=Adam(lr=0.000002),loss=triplet_loss)

# %%
def generator2():
    x=["0.001","0.004", "0.005", "0.006", "0.007",
       "0.008", "0.009", "0.010", "0.011", "0.001", "0.010"]
  #  x=["0.001", "0.004", "0.006", "0.010"]

    for k in x:
        anc,neg,pos=getfiles2(k)
        frac=0.95    
        inds = set(random.sample(list(range(len(neg))), int(frac*len(neg))))
        neg = [n for i,n in enumerate(neg) if i not in inds]
    
        for i in range(len(neg)):
            for j in range(len(pos)):
                anchor=returnimages(gentr,anc)
                positive=returnimages(gentr,pos[j])
                negative=returnimages(forgtr,neg[i])
               # yield ([anc,pos[j],neg[i]])
                yield ([anchor,positive,negative],np.asarray([0]))

# %%
for x in range(2):
    model.fit_generator(generator2(),steps_per_epoch=32,epochs=11)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/11
# 32/32 [==============================] - 44s 279ms/step - loss: 0.0000e+00
# Epoch 2/11
# 32/32 [==============================] - 9s 263ms/step - loss: 0.0000e+00
# Epoch 3/11
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0000e+00
# Epoch 4/11
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0000e+00
# Epoch 5/11
# 32/32 [==============================] - 10s 281ms/step - loss: 0.0000e+00
# Epoch 6/11
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0000e+00
# Epoch 7/11
# 32/32 [==============================] - 9s 284ms/step - loss: 0.0000e+00
# Epoch 8/11
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0000e+00
# Epoch 9/11
# 32/32 [==============================] - 10s 280ms/step - loss: 0.0360
# Epoch 10/11
# 32/32 [==============================] - 9s 278ms/step - loss: 0.0000e+00
# Epoch 11/11
# 32/32 [==============================] - 9s 282ms/step - loss: 0.0000e+00
# Epoch 1/11
# 32/32 [==============================] - 9s 283ms/step - loss: 0.0000e+00
# Epoch 2/11
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0000e+00
# Epoch 3/11
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0000e+00
# Epoch 4/11
# 32/32 [==============================] - 9s 269ms/step - loss: 0.0000e+00
# Epoch 5/11
# 32/32 [==============================] - 9s 269ms/step - loss: 0.0000e+00
# Epoch 6/11
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0000e+00
# Epoch 7/11
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0000e+00
# Epoch 8/11
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0000e+00
# Epoch 9/11
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0000e+00
# Epoch 10/11
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0000e+00
# Epoch 11/11
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0000e+00

# %%
tneg,tpos=0,0
x=[0.002, 0.008, 0.016, 0.018, 0.024, 0.033, 0.035, 0.044, 0.046, 0.063,
   0.070, 0.071, 0.077, 0.084, 0.085, 0.086, 0.089, 0.092, 0.093]
for k in x: #the id of signatures you want to check
    #print("When k is ", k)
    anc,neg,pos=getfiles(k,gent,forgt)
    tneg=tneg+len(neg)
    tpos=tpos+len(pos)
print(tneg,tpos)
# Out:
# 624 203

# %%
model.save_weights('/content/drive/MyDrive/input')

# %%
forg_passed=0
gen_flagged=0
x=[0.002, 0.008, 0.016, 0.018, 0.024, 0.033, 0.035, 0.044, 0.046, 0.063,
   0.070, 0.071, 0.077, 0.084, 0.085, 0.086, 0.089, 0.092, 0.093]

for k in x: #the id of signatures you want to check
    print("When k is ", k)
    anc,neg,pos=getfiles(k,gent,forgt)
    
    anchor=returnimages(gent,anc)
    for i in range(len(pos)): #pos
        positive=returnimages(gent,pos[i])
        x=model.predict([anchor,positive,anchor])
        a, p, useless = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-p)
        dist=np.linalg.norm(a-p)
        # print("positive distance is ",dist)
        if(dist>11204):
        #  print("0")
            gen_flagged=gen_flagged+1
            print("gen flagged - ",dist, "file name is - ", pos[i])
            
        else:
            gen_flagged=gen_flagged
        #   print("1")
        
    for j in range(len(neg)): #neg
        negative=returnimages(forgt,neg[j])
        x=model.predict([anchor,negative,anchor])
        a, n, useless = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-n)
        dist=np.linalg.norm(a-n)
        # print("negative distance is ",dist)
        if(dist>128):
            forg_passed=forg_passed
          #  print("0")
        else:
            forg_passed=forg_passed+1
            print("forg passed - ",dist, "file name is - ", neg[j])
          #  print("1")

print("forg_passed is ",forg_passed)
print("gen_flagged is ",gen_flagged)
# Out:
# When k is  0.002
# When k is  0.008
# When k is  0.016
# When k is  0.018
# gen flagged -  41821.13 file name is -  NFI-01810018.png
# gen flagged -  41821.13 file name is -  NFI-01804018.png
# gen flagged -  41821.13 file name is -  NFI-01811018.png
# gen flagged -  41821.13 file name is -  NFI-01807018.png
# gen flagged -  41821.13 file name is -  NFI-01802018.png
# When k is  0.024
# gen flagged -  27659.535 file name is -  NFI-02401024.png
# gen flagged -  27659.535 file name is -  NFI-02409024.png
# gen flagged -  27659.535 file name is -  NFI-02405024.png
# gen flagged -  27659.535 file name is -  NFI-02402024.png
# gen flagged -  27659.535 file name is -  NFI-02404024.png
# gen flagged -  27659.535 file name is -  NFI-02403024.png
# gen flagged -  27659.535 file name is -  NFI-02410024.png
# gen flagged -  27659.535 file name is -  NFI-02412024.png
# gen flagged -  27659.535 file name is -  NFI-02407024.png
# gen flagged -  27659.535 file name is -  NFI-02411024.png
# gen flagged -  27659.535 file name is -  NFI-02408024.png
# When k is  0.033
# When k is  0.035
# gen flagged -  33261.21 file name is -  NFI-03503035.png
# gen flagged -  33261.21 file name is -  NFI-03501035.png
# gen flagged -  33261.21 file name is -  NFI-03508035.png
# gen flagged -  33261.21 file name is -  NFI-03511035.png
# gen flagged -  33261.21 file name is -  NFI-03505035.png
# gen flagged -  33261.21 file name is -  NFI-03507035.png
# gen flagged -  33261.21 file name is -  NFI-03506035.png
# gen flagged -  33261.21 file name is -  NFI-03510035.png
# gen flagged -  33261.21 file name is -  NFI-03512035.png
# gen flagged -  33261.21 file name is -  NFI-03509035.png
# gen flagged -  33261.21 file name is -  NFI-03502035.png
# When k is  0.044
# When k is  0.046
# When k is  0.063
# When k is  0.07
# gen flagged -  47791.027 file name is -  NFI-07008070.png
# gen flagged -  47791.027 file name is -  NFI-07001070.png
# gen flagged -  47791.027 file name is -  NFI-07007070.png
# gen flagged -  47791.027 file name is -  NFI-07011070.png
# gen flagged -  47791.027 file name is -  NFI-07006070.png
# gen flagged -  47791.027 file name is -  NFI-07004070.png
# gen flagged -  47791.027 file name is -  NFI-07012070.png
# gen flagged -  47791.027 file name is -  NFI-07009070.png
# gen flagged -  47791.027 file name is -  NFI-07003070.png
# gen flagged -  47791.027 file name is -  NFI-07002070.png
# gen flagged -  47791.027 file name is -  NFI-07005070.png
# When k is  0.071
# gen flagged -  50148.504 file name is -  NFI-07106071.png
# gen flagged -  50148.504 file name is -  NFI-07109071.png
# gen flagged -  50148.504 file name is -  NFI-07102071.png
# gen flagged -  50148.504 file name is -  NFI-07112071.png
# gen flagged -  50148.504 file name is -  NFI-07111071.png
# gen flagged -  50148.504 file name is -  NFI-07108071.png
# gen flagged -  50148.504 file name is -  NFI-07103071.png
# gen flagged -  50148.504 file name is -  NFI-07107071.png
# gen flagged -  50148.504 file name is -  NFI-07110071.png
# gen flagged -  50148.504 file name is -  NFI-07104071.png
# gen flagged -  50148.504 file name is -  NFI-07101071.png
# When k is  0.077
# gen flagged -  144507.12 file name is -  NFI-07706077.png
# gen flagged -  144507.12 file name is -  NFI-07701077.png
# gen flagged -  144507.12 file name is -  NFI-07711077.png
# gen flagged -  144507.12 file name is -  NFI-07708077.png
# gen flagged -  144507.12 file name is -  NFI-07704077.png
# gen flagged -  144507.12 file name is -  NFI-07710077.png
# gen flagged -  144507.12 file name is -  NFI-07703077.png
# gen flagged -  144507.12 file name is -  NFI-07707077.png
# gen flagged -  144507.12 file name is -  NFI-07702077.png
# gen flagged -  144507.12 file name is -  NFI-07712077.png
# gen flagged -  144507.12 file name is -  NFI-07709077.png
# When k is  0.084
# When k is  0.085
# gen flagged -  29515.873 file name is -  NFI-08505085.png
# gen flagged -  29515.873 file name is -  NFI-08511085.png
# gen flagged -  29515.873 file name is -  NFI-08501085.png
# gen flagged -  29515.873 file name is -  NFI-08506085.png
# gen flagged -  29515.873 file name is -  NFI-08509085.png
# gen flagged -  29515.873 file name is -  NFI-08507085.png
# gen flagged -  29515.873 file name is -  NFI-08503085.png
# gen flagged -  29515.873 file name is -  NFI-08508085.png
# gen flagged -  29515.873 file name is -  NFI-08512085.png
# gen flagged -  29515.873 file name is -  NFI-08502085.png
# gen flagged -  29515.873 file name is -  NFI-08510085.png
# When k is  0.086
# When k is  0.089
# gen flagged -  38905.402 file name is -  NFI-08909089.png
# gen flagged -  38905.402 file name is -  NFI-08901089.png
# gen flagged -  38905.402 file name is -  NFI-08908089.png
# gen flagged -  38905.402 file name is -  NFI-08906089.png
# gen flagged -  38905.402 file name is -  NFI-08904089.png
# gen flagged -  38905.402 file name is -  NFI-08902089.png
# gen flagged -  38905.402 file name is -  NFI-08911089.png
# gen flagged -  38905.402 file name is -  NFI-08903089.png
# gen flagged -  38905.402 file name is -  NFI-08912089.png
# gen flagged -  38905.402 file name is -  NFI-08905089.png
# gen flagged -  38905.402 file name is -  NFI-08910089.png
# When k is  0.092
# gen flagged -  111164.3 file name is -  NFI-09212092.png
# gen flagged -  111164.3 file name is -  NFI-09204092.png
# gen flagged -  111164.3 file name is -  NFI-09201092.png
# gen flagged -  111164.3 file name is -  NFI-09210092.png
# gen flagged -  111164.3 file name is -  NFI-09203092.png
# gen flagged -  111164.3 file name is -  NFI-09206092.png
# gen flagged -  111164.3 file name is -  NFI-09202092.png
# gen flagged -  111164.3 file name is -  NFI-09209092.png
# gen flagged -  111164.3 file name is -  NFI-09208092.png
# gen flagged -  111164.3 file name is -  NFI-09205092.png
# gen flagged -  111164.3 file name is -  NFI-09207092.png
# When k is  0.093
# gen flagged -  86196.06 file name is -  NFI-09309093.png
# gen flagged -  86196.06 file name is -  NFI-09308093.png
# gen flagged -  86196.06 file name is -  NFI-09307093.png
# gen flagged -  86196.06 file name is -  NFI-09305093.png
# gen flagged -  86196.06 file name is -  NFI-09310093.png
# gen flagged -  86196.06 file name is -  NFI-09306093.png
# gen flagged -  86196.06 file name is -  NFI-09301093.png
# gen flagged -  86196.06 file name is -  NFI-09302093.png
# gen flagged -  86196.06 file name is -  NFI-09304093.png
# gen flagged -  86196.06 file name is -  NFI-09311093.png
# gen flagged -  86196.06 file name is -  NFI-09303093.png
# forg_passed is  0
# gen_flagged is  104

# %%
def getfilest(num,gen,forg):
    a=os.listdir(gen)
    b=os.listdir(forg)
    c=str(num)
    c=c[2:]
    if(len(c)==2):
        c=c+"0"
    
    n,m=[],[]
    for i in b:
        if i.endswith(c+".png"):
            n=n+[i]
        elif i.endswith(c+".PNG"):
            n=n+[i]
    for i in a:
        if i.endswith(c+".png"):
            m=m+[i]
        elif i.endswith(c+".PNG"):
            m=m+[i]
    return m.pop(),m.pop(),n,m

# %%
forg_passed=0
gen_flagged=0
x=[0.002, 0.008, 0.016, 0.018, 0.024, 0.033, 0.035, 0.044, 0.046, 0.063,
   0.070, 0.071, 0.077, 0.084, 0.085, 0.086, 0.089, 0.092, 0.093]

for k in x: #the id of signatures you want to check
    print("When k is ", k)
    anc1,anc2,neg,pos=getfilest(k,gent,forgt)
    
    anchor1=returnimages(gent,anc1)
    anchor2=returnimages(gent,anc2)
    for i in range(len(pos)): #pos
        positive=returnimages(gent,pos[i])
        x=model.predict([anchor1,positive,anchor2])
        a1, p, a2 = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-p)
        dist1=np.linalg.norm(a1-p)
        dist2=np.linalg.norm(a2-p)
        dist=(dist1+dist2)/2
        #print("positive distance is ",dist)
        if(dist>20000):
        #  print("0")
            gen_flagged=gen_flagged+1
            print("gen flagged - ",dist, "file name is - ", pos[i])
            
        else:
            gen_flagged=gen_flagged
        #   print("1")
        
    for j in range(len(neg)): #neg
        negative=returnimages(forgt,neg[j])
        x=model.predict([anchor1,negative,anchor2])
        a1, n, a2 = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-n)
        dist1=np.linalg.norm(a1-n)
        dist2=np.linalg.norm(a2-n)
        #print("negative distance is ",dist)
        dist=(dist1+dist2)/2
        if(dist>2000):
            forg_passed=forg_passed
          #  print("0")
        else:
            forg_passed=forg_passed+1
            print("forg passed - ",dist, "file name is - ", neg[j])
          #  print("1")

print("forg_passed is ",forg_passed)
print("gen_flagged is ",gen_flagged)
# Out:
# When k is  0.002
# When k is  0.008
# When k is  0.016
# When k is  0.018
# gen flagged -  41701.1171875 file name is -  NFI-01810018.png
# gen flagged -  41701.1171875 file name is -  NFI-01804018.png
# gen flagged -  41701.1171875 file name is -  NFI-01811018.png
# gen flagged -  41701.1171875 file name is -  NFI-01807018.png
# When k is  0.024
# gen flagged -  27715.7734375 file name is -  NFI-02401024.png
# gen flagged -  27715.7734375 file name is -  NFI-02409024.png
# gen flagged -  27715.7734375 file name is -  NFI-02405024.png
# gen flagged -  27715.7734375 file name is -  NFI-02402024.png
# gen flagged -  27715.7734375 file name is -  NFI-02404024.png
# gen flagged -  27715.7734375 file name is -  NFI-02403024.png
# gen flagged -  27715.7734375 file name is -  NFI-02410024.png
# gen flagged -  27715.7734375 file name is -  NFI-02412024.png
# gen flagged -  27715.7734375 file name is -  NFI-02407024.png
# gen flagged -  27715.7734375 file name is -  NFI-02411024.png
# When k is  0.033
# When k is  0.035
# gen flagged -  33076.5859375 file name is -  NFI-03503035.png
# gen flagged -  33076.5859375 file name is -  NFI-03501035.png
# gen flagged -  33076.5859375 file name is -  NFI-03508035.png
# gen flagged -  33076.5859375 file name is -  NFI-03511035.png
# gen flagged -  33076.5859375 file name is -  NFI-03505035.png
# gen flagged -  33076.5859375 file name is -  NFI-03507035.png
# gen flagged -  33076.5859375 file name is -  NFI-03506035.png
# gen flagged -  33076.5859375 file name is -  NFI-03510035.png
# gen flagged -  33076.5859375 file name is -  NFI-03512035.png
# gen flagged -  33076.5859375 file name is -  NFI-03509035.png
# When k is  0.044
# forg passed -  164.76983642578125 file name is -  NFI-01302044.png
# forg passed -  164.76983642578125 file name is -  NFI-00901044.png
# forg passed -  164.76983642578125 file name is -  NFI-08006044.png
# forg passed -  164.76983642578125 file name is -  NFI-08003044.png
# forg passed -  164.76983642578125 file name is -  NFI-00404044.png
# forg passed -  164.76983642578125 file name is -  NFI-01405044.png
# forg passed -  164.76983642578125 file name is -  NFI-00903044.png
# forg passed -  164.76983642578125 file name is -  NFI-01401044.png
# forg passed -  164.76983642578125 file name is -  NFI-01303044.png
# forg passed -  164.76983642578125 file name is -  NFI-01403044.png
# forg passed -  164.76983642578125 file name is -  NFI-00606044.png
# forg passed -  164.76983642578125 file name is -  NFI-01306044.png
# forg passed -  164.76983642578125 file name is -  NFI-00604044.png
# forg passed -  164.76983642578125 file name is -  NFI-00401044.png
# forg passed -  164.76983642578125 file name is -  NFI-01305044.png
# forg passed -  164.76983642578125 file name is -  NFI-08001044.png
# forg passed -  164.76983642578125 file name is -  NFI-08005044.png
# forg passed -  164.76983642578125 file name is -  NFI-01404044.png
# forg passed -  164.76983642578125 file name is -  NFI-00403044.png
# forg passed -  164.76983642578125 file name is -  NFI-00905044.png
# forg passed -  164.76983642578125 file name is -  NFI-01301044.png
# forg passed -  164.76983642578125 file name is -  NFI-00406044.png
# forg passed -  164.76983642578125 file name is -  NFI-01304044.png
# forg passed -  164.76983642578125 file name is -  NFI-00906044.png
# forg passed -  164.76983642578125 file name is -  NFI-00605044.png
# forg passed -  164.76983642578125 file name is -  NFI-08002044.png
# forg passed -  164.76983642578125 file name is -  NFI-00603044.png
# forg passed -  164.76983642578125 file name is -  NFI-00405044.png
# forg passed -  164.76983642578125 file name is -  NFI-08004044.png
# forg passed -  164.76983642578125 file name is -  NFI-00601044.png
# forg passed -  164.76983642578125 file name is -  NFI-00402044.png
# forg passed -  164.76983642578125 file name is -  NFI-01402044.png
# forg passed -  164.76983642578125 file name is -  NFI-00904044.png
# forg passed -  164.76983642578125 file name is -  NFI-00602044.png
# forg passed -  164.76983642578125 file name is -  NFI-01406044.png
# forg passed -  164.76983642578125 file name is -  NFI-00902044.png
# When k is  0.046
# When k is  0.063
# When k is  0.07
# gen flagged -  47689.3359375 file name is -  NFI-07008070.png
# gen flagged -  47689.3359375 file name is -  NFI-07001070.png
# gen flagged -  47689.3359375 file name is -  NFI-07007070.png
# gen flagged -  47689.3359375 file name is -  NFI-07011070.png
# gen flagged -  47689.3359375 file name is -  NFI-07006070.png
# gen flagged -  47689.3359375 file name is -  NFI-07004070.png
# gen flagged -  47689.3359375 file name is -  NFI-07012070.png
# gen flagged -  47689.3359375 file name is -  NFI-07009070.png
# gen flagged -  47689.3359375 file name is -  NFI-07003070.png
# gen flagged -  47689.3359375 file name is -  NFI-07002070.png
# When k is  0.071
# gen flagged -  49875.4765625 file name is -  NFI-07106071.png
# gen flagged -  49875.4765625 file name is -  NFI-07109071.png
# gen flagged -  49875.4765625 file name is -  NFI-07102071.png
# gen flagged -  49875.4765625 file name is -  NFI-07112071.png
# gen flagged -  49875.4765625 file name is -  NFI-07111071.png
# gen flagged -  49875.4765625 file name is -  NFI-07108071.png
# gen flagged -  49875.4765625 file name is -  NFI-07103071.png
# gen flagged -  49875.4765625 file name is -  NFI-07107071.png
# gen flagged -  49875.4765625 file name is -  NFI-07110071.png
# gen flagged -  49875.4765625 file name is -  NFI-07104071.png
# When k is  0.077
# gen flagged -  144638.1875 file name is -  NFI-07706077.png
# gen flagged -  144638.1875 file name is -  NFI-07701077.png
# gen flagged -  144638.1875 file name is -  NFI-07711077.png
# gen flagged -  144638.1875 file name is -  NFI-07708077.png
# gen flagged -  144638.1875 file name is -  NFI-07704077.png
# gen flagged -  144638.1875 file name is -  NFI-07710077.png
# gen flagged -  144638.1875 file name is -  NFI-07703077.png
# gen flagged -  144638.1875 file name is -  NFI-07707077.png
# gen flagged -  144638.1875 file name is -  NFI-07702077.png
# gen flagged -  144638.1875 file name is -  NFI-07712077.png
# When k is  0.084
# forg passed -  1231.00830078125 file name is -  NFI-04104084.png
# forg passed -  1231.00830078125 file name is -  NFI-03203084.png
# forg passed -  1231.00830078125 file name is -  NFI-04203084.png
# forg passed -  1231.00830078125 file name is -  NFI-03904084.png
# forg passed -  1231.00830078125 file name is -  NFI-03905084.png
# forg passed -  1231.00830078125 file name is -  NFI-04201084.png
# forg passed -  1231.00830078125 file name is -  NFI-03202084.png
# forg passed -  1231.00830078125 file name is -  NFI-04906084.png
# forg passed -  1231.00830078125 file name is -  NFI-03906084.png
# forg passed -  1231.00830078125 file name is -  NFI-04901084.png
# forg passed -  1231.00830078125 file name is -  NFI-03902084.png
# forg passed -  1231.00830078125 file name is -  NFI-04102084.png
# forg passed -  1231.00830078125 file name is -  NFI-04202084.png
# forg passed -  1231.00830078125 file name is -  NFI-04306084.png
# forg passed -  1231.00830078125 file name is -  NFI-03903084.png
# forg passed -  1231.00830078125 file name is -  NFI-04206084.png
# forg passed -  1231.00830078125 file name is -  NFI-03204084.png
# forg passed -  1231.00830078125 file name is -  NFI-04105084.png
# forg passed -  1231.00830078125 file name is -  NFI-04902084.png
# forg passed -  1231.00830078125 file name is -  NFI-04103084.png
# forg passed -  1231.00830078125 file name is -  NFI-04304084.png
# forg passed -  1231.00830078125 file name is -  NFI-04905084.png
# forg passed -  1231.00830078125 file name is -  NFI-04301084.png
# forg passed -  1231.00830078125 file name is -  NFI-04903084.png
# forg passed -  1231.00830078125 file name is -  NFI-03901084.png
# forg passed -  1231.00830078125 file name is -  NFI-03201084.png
# forg passed -  1231.00830078125 file name is -  NFI-03206084.png
# forg passed -  1231.00830078125 file name is -  NFI-04205084.png
# forg passed -  1231.00830078125 file name is -  NFI-04106084.png
# forg passed -  1231.00830078125 file name is -  NFI-04101084.png
# forg passed -  1231.00830078125 file name is -  NFI-04904084.png
# forg passed -  1231.00830078125 file name is -  NFI-04302084.png
# forg passed -  1231.00830078125 file name is -  NFI-03205084.png
# forg passed -  1231.00830078125 file name is -  NFI-04303084.png
# forg passed -  1231.00830078125 file name is -  NFI-04204084.png
# forg passed -  1231.00830078125 file name is -  NFI-04305084.png
# When k is  0.085
# gen flagged -  29175.091796875 file name is -  NFI-08505085.png
# gen flagged -  29175.091796875 file name is -  NFI-08511085.png
# gen flagged -  29175.091796875 file name is -  NFI-08501085.png
# gen flagged -  29175.091796875 file name is -  NFI-08506085.png
# gen flagged -  29175.091796875 file name is -  NFI-08509085.png
# gen flagged -  29175.091796875 file name is -  NFI-08507085.png
# gen flagged -  29175.091796875 file name is -  NFI-08503085.png
# gen flagged -  29175.091796875 file name is -  NFI-08508085.png
# gen flagged -  29175.091796875 file name is -  NFI-08512085.png
# gen flagged -  29175.091796875 file name is -  NFI-08502085.png
# When k is  0.086
# When k is  0.089
# gen flagged -  38222.6875 file name is -  NFI-08909089.png
# gen flagged -  38222.6875 file name is -  NFI-08901089.png
# gen flagged -  38222.6875 file name is -  NFI-08908089.png
# gen flagged -  38222.6875 file name is -  NFI-08906089.png
# gen flagged -  38222.6875 file name is -  NFI-08904089.png
# gen flagged -  38222.6875 file name is -  NFI-08902089.png
# gen flagged -  38222.6875 file name is -  NFI-08911089.png
# gen flagged -  38222.6875 file name is -  NFI-08903089.png
# gen flagged -  38222.6875 file name is -  NFI-08912089.png
# gen flagged -  38222.6875 file name is -  NFI-08905089.png
# When k is  0.092
# gen flagged -  112100.8203125 file name is -  NFI-09212092.png
# gen flagged -  112100.8203125 file name is -  NFI-09204092.png
# gen flagged -  112100.8203125 file name is -  NFI-09201092.png
# gen flagged -  112100.8203125 file name is -  NFI-09210092.png
# gen flagged -  112100.8203125 file name is -  NFI-09203092.png
# gen flagged -  112100.8203125 file name is -  NFI-09206092.png
# gen flagged -  112100.8203125 file name is -  NFI-09202092.png
# gen flagged -  112100.8203125 file name is -  NFI-09209092.png
# gen flagged -  112100.8203125 file name is -  NFI-09208092.png
# gen flagged -  112100.8203125 file name is -  NFI-09205092.png
# When k is  0.093
# gen flagged -  86391.71875 file name is -  NFI-09309093.png
# gen flagged -  86391.71875 file name is -  NFI-09308093.png
# gen flagged -  86391.71875 file name is -  NFI-09307093.png
# gen flagged -  86391.71875 file name is -  NFI-09305093.png
# gen flagged -  86391.71875 file name is -  NFI-09310093.png
# gen flagged -  86391.71875 file name is -  NFI-09306093.png
# gen flagged -  86391.71875 file name is -  NFI-09301093.png
# gen flagged -  86391.71875 file name is -  NFI-09302093.png
# gen flagged -  86391.71875 file name is -  NFI-09304093.png
# gen flagged -  86391.71875 file name is -  NFI-09311093.png
# forg_passed is  72
# gen_flagged is  94
